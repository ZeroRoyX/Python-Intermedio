# %%
import os
from random import choice

def run():
    os.system("clear")
    print("Guess the word!")
    with open("./hangman_file/data.txt") as f:
        # mylist = list(map(lambda x: x, filter(lambda x: x.split("\n"), f)))
        mylist = list(map(lambda x: x.strip(), f))
        f.close()
    # print(mylist)
    chosen_word = choice(mylist)
    print(chosen_word)
    word_length = len(chosen_word)
    underscore = ((word_length - 1) * '_ ' + '_')
    print(underscore)

    letter = input("Please insert a letter: ")
    a = 0
    another_list = [i for i in range(word_length) if letter == chosen_word[i]]
    another_list = str(another_list)
    another_list = "".join(another_list)
    another_list = int(another_list)
    # underscore = underscore.insert()
    print(another_list)
    
    # another_list = [a for i in chosen_word if letter == i a += 1]
    # for i in chosen_word:
    #     print(i)
    #     if letter == i:
    #         index = a
    #         print(index)
    #     a += 1
    
    # underscore 

    # print(chosen_word.index(letter))

    # if letter in chosen_word
    #     print('Included')
    # else:
    #     print('not')

            


if __name__ == '__main__':
    run()

# %%
import os
from random import choice

def clear():
    os.system("clear")

def run():
    clear()
    print("Guess the word!")
    with open("./hangman_file/data.txt") as f:
        my_list = [i.strip() for i in f]
        f.close()
    
    chosen_word = choice(my_list)
    print(chosen_word)
    unknown_word = [i for i in chosen_word] # Each letter as an element in the list.
    # print(unknown_word)
    unknown_word = [i.replace(i, "_") for i in chosen_word] # Each letter replaced by a "_".
    # print(unknown_word)   
    unknown_text = " ".join(unknown_word) # Concantes all the letters with a space betweeen each one.
    # unknown_word = unknown_word.replace(, "_")
    print(unknown_text)
    # print(unknown_word)
        
    
        

    while chosen_word != "".join(unknown_word):
        letter = input("Type a letter: ")
    
        # correct = [letter for letter, index in enumerate(chosen_word)]
        # print(correct)
        for a, b in enumerate(chosen_word):
            if letter == b:
                unknown_word[a] = letter
                # print(unknown_word)

        unknown_text = " ".join(unknown_word)
        print(unknown_text)
        clear()
        

    else:
        print("YOU WON!")

    
            # print(unknown_word.replace("_", letter)) 
            # print(a)
        # print(a, b)


        # my_dict = {line.strip("\n"): len(line.strip()) for line in f}
        # my_list = [i for i in my_dict.keys()]
        

        # new_dict = {}
        # for i in my_dict.keys():
        #     new_dict[i] = ({'name': i})
        

        # my_list = enumerate(my_list)
        # new_dict = {i for i in my_list}
        # print(new_dict)
        # f.close()
    
    # chosen_word = choice(my_dict.keys())
    # print(chosen_word)


if __name__ == '__main__':
    run()

# %%
import os
from random import choice
from sketches import HANGMANPICS

def clear():
    os.system("clear")

def run():
    clear()
    with open("./hangman_file/data.txt") as f:
        my_list = [i.strip() for i in f]
        f.close()
    
    chosen_word = choice(my_list)
    print(chosen_word)
    unknown_word = [i for i in chosen_word] # Each letter as an element in the list.
    # print(unknown_word)
    unknown_word = [i.replace(i, "_") for i in chosen_word] # Each letter replaced by a "_".
    # print(unknown_word)   
    unknown_text = " ".join(unknown_word) # Concantes all the letters with a space betweeen each one.
    # unknown_word = unknown_word.replace(, "_")
    # print(unknown_word)
    continue = 5

      

    while chosen_word != "".join(unknown_word) and continue > 0:
        
        
        clear()
        print("Guess the word!")
        print(unknown_text)
        letter = input("Type a letter: ")
    
        # correct = [letter for letter, index in enumerate(chosen_word)]
        # print(correct)
        for a, b in enumerate(chosen_word):
            if letter == b:
                unknown_word[a] = letter
                # print(unknown_word)


            else:
                for c, d in enumerate(HANGMANPICS):
                    sketch = HANGMANPICS[i]
                # sketch = [i for i in HANGMANPICS]

        unknown_text = " ".join(unknown_word)
        print(unknown_text)
        print(sketch)
        i += 1
        # clear()
        

    else:
        print("YOU WON! The word was: " + chosen_word)

    
            # print(unknown_word.replace("_", letter)) 
            # print(a)
        # print(a, b)


        # my_dict = {line.strip("\n"): len(line.strip()) for line in f}
        # my_list = [i for i in my_dict.keys()]
        

        # new_dict = {}
        # for i in my_dict.keys():
        #     new_dict[i] = ({'name': i})
        

        # my_list = enumerate(my_list)
        # new_dict = {i for i in my_list}
        # print(new_dict)
        # f.close()
    
    # chosen_word = choice(my_dict.keys())
    # print(chosen_word)


if __name__ == '__main__':
    run()

# %%
import os
from random import choice
from sketches import HANGMANPICS

def clear():
    os.system("clear")

def run():
    clear()
    with open("./hangman_file/data.txt") as f:
        my_list = [i.strip() for i in f]
        f.close()
    
    chosen_word = choice(my_list)
    print(chosen_word)
    unknown_word = [i for i in chosen_word] # Each letter as an element in the list.
    print(unknown_word)
    underscore_word = [i.replace(i, "_") for i in chosen_word] # Each letter replaced by a "_".
    # print(unknown_word)   
    unknown_text = " ".join(underscore_word) # Concantes all the letters with a space betweeen each one.
    # unknown_word = unknown_word.replace(, "_")
    # print(unknown_word)
    continues = 7

      

    while chosen_word != "".join(underscore_word):

        if continues == 0:
            clear()
            print("GAME OVER 😭")
            print("")
            break
        
        
        c = HANGMANPICS[7 - continues]
        clear()
        print(continues)
        if continues <= 7:
            print(c)
            print("")
        print("Guess the word!")
        print(unknown_text)
        letter = input("Type a letter: ")
    
        # correct = [letter for letter, index in enumerate(chosen_word)]
        # print(correct)
        for a, b in enumerate(chosen_word):
            if letter == b:
                underscore_word[a] = letter
                unknown_text = " ".join(underscore_word)
                # print(unknown_word)

            else:
                continue
        
        clear()

        if letter not in unknown_word:
            continues -= 1
                
                
            # sketch = [i for i in HANGMANPICS]

        # print(unknown_text)
        # clear()
        

    else:
        print("YOU WON! 🏆 The word was: " + chosen_word + "✨" )
        print("")

    
            # print(unknown_word.replace("_", letter)) 
            # print(a)
        # print(a, b)


        # my_dict = {line.strip("\n"): len(line.strip()) for line in f}
        # my_list = [i for i in my_dict.keys()]
        

        # new_dict = {}
        # for i in my_dict.keys():
        #     new_dict[i] = ({'name': i})
        

        # my_list = enumerate(my_list)
        # new_dict = {i for i in my_list}
        # print(new_dict)
        # f.close()
    
    # chosen_word = choice(my_dict.keys())
    # print(chosen_word)


if __name__ == '__main__':
    run()

# %%
import os
from random import choice
from sketches import HANGMANPICS
import unicodedata

def clear():
    os.system("clear")

def opening_file():
    with open("./hangman_file/data.txt") as f:
        my_list = [i.strip() for i in f]
        f.close()
    return my_list

def strip_accents(text):
    text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
    return str(text)

def run():
    clear()
    # opening_file()
    
    chosen_word = choice(opening_file())
    no_accents = strip_accents(chosen_word)
    unknown_word = [i for i in chosen_word] # Each letter as an element in the list.
    print(unknown_word)
    underscore_word = [i.replace(i, "_") for i in chosen_word] # Each letter replaced by a "_".
    unknown_text = " ".join(underscore_word) # Concantes all the letters with a space betweeen each one.
    continues = 7      
    list_used_letters = []

    while chosen_word != "".join(underscore_word):

        if continues == 0:
            clear()
            print("YOU LOSE! 😲 The word was: " + chosen_word.capitalize() + " 👀")
            print("")
            print("GAME OVER 😭")
            print("")
            break        
        
        c = HANGMANPICS[7 - continues]
        used_letters = " ".join(list_used_letters)
        clear()
        print(chosen_word)
        print(f'CONTINUES: {continues}')
        print(c)
        print("")
        print("Guess the word! 📝")
        print(unknown_text)
        print("")
        print("Letters used: " + used_letters)
        print("")
        letter = input("Type a letter: ").lower()

        try:
            if len(letter.strip()) == 0:
                raise Exception("Blank is not allowed. Please type a letter. Press Enter.")
            elif letter.isnumeric() == True:
                raise Exception("Numbers are not allowed, please use only a letter. Press Enter.")
            elif letter.isalpha() == False:
                raise Exception("No signs or puctuation marks allowed. Please use only an alphabet letter. Press Enter.")
            elif len(letter) > 1:
                if letter == no_accents:
                    clear()
                    print("🏆 YOU WON!  The word was: ✨ " + chosen_word.capitalize() +  " ✨" )
                    print("")
                    break
                elif len(letter) == len(chosen_word) and letter != chosen_word:
                    continues -= 1
                    raise Exception("Not the word we are looking for. Try again.")
                else:
                    raise Exception("Please just type one letter. Press Enter.")
            elif letter in list_used_letters:
                raise Exception("Letter already used. Please use another letter. Press Enter.")

            for i in letter:
                list_used_letters.append(i)
            # list_used_letters = list_used_letters.append(letter)
            letter = strip_accents(letter)

            for a, b in enumerate(no_accents):
                if letter == b:
                    underscore_word[a] = chosen_word[a] # letter
                    unknown_text = " ".join(underscore_word)

                else:
                    continue
            
            if letter not in unknown_word:
                continues -= 1

        except Exception as ex:
            print(input(ex))          
                      
    else:
        clear()
        print("🏆 YOU WON!  The word was: ✨ " + chosen_word.capitalize() +  " ✨" )
        print("")    

if __name__ == '__main__':
    run()

# %%
# import the time module
import time
  
# define the countdown func.
def countdown(t):
    
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        print(timer, end="\r")
        time.sleep(1)
        t -= 1
      
    print('Fire in the hole!!')
  
  
# input time in seconds
t = input("Enter the time in seconds: ")
  
# function call
countdown(int(t))

# %%
s = 'as32{ vd"s k!+'
print(''.join(x for x in s if x.isalpha()))
   
print(filter(str.isalpha, s)) # works in python-2.7

print(''.join(filter(lambda x: not x.isnumeric() and not x.isalpha(), s))) # works in python3
# print("".join(list(filter(lambda x: x.isalpha(), s))))

# %%
import random
import os


def read_data(filepath="./hangman_file/data.txt"):
    words = []
    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            words.append(line.strip().upper())
    return words


def run():
    data = read_data(filepath="./hangman_file/data.txt")
    chosen_word = random.choice(data)
    chosen_word_list = [letter for letter in chosen_word]
    print(chosen_word_list)
    chosen_word_list_underscores = ["_"] * len(chosen_word_list)
    print(chosen_word_list_underscores)
    letter_index_dict = {}
    for idx, letter in enumerate(chosen_word):
        # print(idx, letter)
        # print(letter_index_dict.get(letter))
        if not letter_index_dict.get(letter): 
            letter_index_dict[letter] = []
            # print(letter_index_dict)
        letter_index_dict[letter].append(idx)
        # print(letter_index_dict)
        # print(letter_index_dict.get(letter))
    
    # while True:
    #     os.system("cls") # Si estás en Unix (Mac o Linux) cambia cls por clear
    #     print("¡Adivina la palabra!")
    for element in chosen_word_list:
        print(element)
        print(element + " ", end="")
    # print("\n")

        # letter = input("Ingresa una letra: ").strip().upper()
        # assert letter.isalpha(), "Solo puedes ingresar letras"

        # if letter in chosen_word_list:
        #     for idx in letter_index_dict[letter]:
        #         chosen_word_list_underscores[idx] = letter
        
        # if "_" not in chosen_word_list_underscores:
        #     os.system("cls") # Si estás en Unix (Mac o Linux) cambia cls por clear
        #     print("¡Ganaste! La palabra era", chosen_word)
        #     break


if __name__ == '__main__':
    run()
# Out:
# ['T', 'E', 'C', 'L', 'A']
# ['_', '_', '_', '_', '_']
# T
# T E
# E C
# C L
# L A
# A
